# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation",
    huggingfacehub_api_token=os.getenv('HUGGINGFACEHUB_API_TOKEN')
)

model = ChatHuggingFace(llm=llm)

# %%
class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLMState)->LLMState:
    question=state['question']

    prompt=f'Answer the following question:{question}'

    res=model.invoke(prompt)
    state['answer']=res.content
    return state

# %%
graph=StateGraph(LLMState)

graph.add_node('llm_qa',llm_qa)

graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

workflow=graph.compile()

final_state=workflow.invoke({
    'question': "What is the distance between Moon and the Earth?"
})

# %%
print(final_state['answer'])
# Out:
# The average distance between the Earth and the Moon is approximately 384,400 kilometers (238,900 miles). However, this distance can vary due to the elliptical shape of the Moon's orbit around the Earth.
#
# At its closest point, known as perigee, the distance between the Earth and the Moon is about 363,300 kilometers (225,300 miles).
#
# At its farthest point, known as apogee, the distance between the Earth and the Moon is about 405,500 kilometers (252,000 miles).
#
# So, the distance between the Earth and the Moon can vary between approximately 363,300 and 405,500 kilometers, but the average distance is about 384,400 kilometers.
